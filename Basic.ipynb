# %% [markdown]
# # Models can be utilized in two ways:
#     1.With agents - Models can be dynamically specified when creating an agent.
#     2.Standalone - Models can be called directly (outside of the agent loop) for tasks like text generation, classification, or extraction without the need for an agent framework.

# %% [markdown]
# # Standalone method

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = "AAAAAAAAAAAAAAAAAA"

model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
response=model.invoke("What is the color of mango")
response
# Out:
# AIMessage(content='The color of a mango can vary quite a bit depending on the variety and ripeness, but generally, you\'ll see a beautiful spectrum of **yellows, oranges, and reds**.\n\nHere\'s a breakdown of what you might encounter:\n\n*   **Yellow:** This is probably the most common and iconic mango color. Ripe mangoes often have a bright, sunny yellow skin.\n*   **Orange:** Many mangoes deepen into a rich, vibrant orange as they ripen, sometimes with hints of red.\n*   **Red:** Some varieties have significant red blushing or even a predominantly red skin. This red can range from a bright crimson to a deeper maroon.\n*   **Green:** Unripe mangoes are typically green. Some varieties may retain a greenish hue even when ripe, but they will usually be softer and sweeter.\n*   **Blushes and Mottling:** It\'s very common to see a mix of these colors. A mango might be primarily yellow with patches of red or orange, or vice-versa.\n\n**In summary, while "yellow" is a good general answer, 
# ...

# %%
print(response.content)
# Out:
# The color of a mango can vary quite a bit depending on the variety and ripeness, but generally, you'll see a beautiful spectrum of **yellows, oranges, and reds**.
#
# Here's a breakdown of what you might encounter:
#
# *   **Yellow:** This is probably the most common and iconic mango color. Ripe mangoes often have a bright, sunny yellow skin.
# *   **Orange:** Many mangoes deepen into a rich, vibrant orange as they ripen, sometimes with hints of red.
# *   **Red:** Some varieties have significant red blushing or even a predominantly red skin. This red can range from a bright crimson to a deeper maroon.
# *   **Green:** Unripe mangoes are typically green. Some varieties may retain a greenish hue even when ripe, but they will usually be softer and sweeter.
# *   **Blushes and Mottling:** It's very common to see a mix of these colors. A mango might be primarily yellow with patches of red or orange, or vice-versa.
#
# ...

# %% [markdown]
# # Parameters:
#     1.Temperature : Controls the randomness of the model’s output. A higher number makes responses more creative; lower ones make them more deterministic
#     2.Max tokens : Limits the total number of tokens in the response, effectively controlling how long the output can be.
#     3.timeout : The maximum time (in seconds) to wait for a response from the model before canceling the request.
#     4.max retries : The maximum number of attempts the system will make to resend a request if it fails due to issues like network timeouts or rate limits.

# %%
model2=init_chat_model("google_genai:gemini-2.5-flash-lite", temperature=1.0)
response2=model2.invoke("What is Data science")
print(response2.content)
# Out:
# Data science is a **multidisciplinary field that uses scientific methods, processes, algorithms, and systems to extract knowledge and insights from data in various forms, both structured and unstructured.** Essentially, it's about **turning raw data into actionable information and knowledge.**
#
# Think of it as a blend of statistics, computer science, domain expertise, and visualization. Data scientists aim to understand complex phenomena, make predictions, and inform decision-making by analyzing data.
#
# Here's a breakdown of the key components and aspects of data science:
#
# **1. Core Components:**
#
# *   **Statistics & Probability:** Understanding statistical concepts is crucial for analyzing data, identifying patterns, testing hypotheses, and quantifying uncertainty.
# ...

# %% [markdown]
# # With agents

# %%
from langchain.agents import create_agent
agent = create_agent("google_genai:gemini-2.5-flash-lite" )
#response=agent.invoke("What is Data science")
#print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from langchain.agents import create_agent
#       2 agent = create_agent("google_genai:gemini-2.5-flash-lite" )
#
# ImportError: cannot import name 'create_agent' from 'langchain.agents' (C:\Users\deept\anaconda3\Lib\site-packages\langchain\agents\__init__.py)

# %%
# !pip install --upgrade langchain
# Out:
# ...
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.2.6
#     Uninstalling langsmith-0.2.6:
#       Successfully uninstalled langsmith-0.2.6
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.28
#     Uninstalling langchain-core-0.3.28:
#       Successfully uninstalled langchain-core-0.3.28
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.13
#     Uninstalling langchain-0.3.13:
#       Successfully uninstalled langchain-0.3.13
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-chroma 0.1.4 requires langchain-core<0.4,>=0.1.40; python_version >= "3.9", but you have langchain-core 1.2.7 which is incompatible.
# langchain-community 0.3.13 requires langchain<0.4.0,>=0.3.13, but you have langchain 1.2.3 which is incompatible.
# ...
